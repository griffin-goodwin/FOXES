# %%
import numpy as np

# %%
test = np.load("/mnt/data2/ML-Ready/AIA-Data/2023-07-01T00:04:00.npy")

# %%
print(test)
# Out:
# [[[-1.         -1.         -1.         ... -0.2892516  -1.
#    -1.        ]
#   [-1.         -0.07722512 -1.         ... -0.45712495 -1.
#    -1.        ]
#   [-0.46481022 -1.         -1.         ... -1.         -1.
#    -0.7440533 ]
#   ...
#   [-0.4354324  -1.         -1.         ... -1.         -0.4053285
#    -1.        ]
#   [-1.         -0.29893303 -0.6437097  ... -0.30624086 -0.43364072
#    -1.        ]
#   [-1.         -1.         -1.         ... -0.6655513  -0.23600407
#    -0.76385206]]
#
#  [[-1.         -1.         -0.88120556 ... -1.         -0.6365499
#    -0.34579757]
#   [-1.         -0.49392632 -0.91880924 ... -1.         -1.
#    -1.        ]
#   [-1.         -0.36136094 -1.         ... -1.         -0.70877236
#    -1.        ]
#   ...
#   [-1.         -0.59927255 -0.6226793  ... -1.         -1.
#    -0.3933657 ]
#   [-0.6596306  -0.4814119  -0.57141227 ... -0.61434567 -1.
#    -1.        ]
#   [-0.5620108  -0.6400741  -0.8955249  ... -0.63742113 -0.5120705
# ...
