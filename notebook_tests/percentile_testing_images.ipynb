# %%
import h5py
import matplotlib.pyplot as plt
from pathlib import Path
import pandas as pd

# Set the path to the normalized data
data_path = Path("/mnt/data/Normalized_Data")

# Function to read and display information from h5 files
def read_h5_files(path):
    # Get all h5 files in the directory
    h5_files = list(path.glob("*.h5"))
    
    if not h5_files:
        print(f"No .h5 files found in {path}")
        return
    
    print(f"Found {len(h5_files)} .h5 files")
    
    # Read the first file to see its structure
    sample_file = h5_files[0]
    print(f"\nExamining sample file: {sample_file.name}")
    
    with h5py.File(sample_file, 'r') as f:
        # Print the keys/groups in the file
        print("\nFile structure:")
        for key in f.keys():
            print(f"- {key}")
            
            # If it's a dataset, show its shape and dtype
            if isinstance(f[key], h5py.Dataset):
                print(f"  Shape: {f[key].shape}, Type: {f[key].dtype}")
            
            # If it's a group, show its keys
            elif isinstance(f[key], h5py.Group):
                print(f"  Subgroups/datasets: {list(f[key].keys())}")
    
    return h5_files

# Read the h5 files
h5_files = read_h5_files(data_path)
# Out:
# Found 38 .h5 files
#
# Examining sample file: aia131_batch5_data_20250710_043518.h5
#
# File structure:
# - normalized_data_0
#   Shape: (13866348,), Type: float64
# - normalized_data_1
#   Shape: (13935107,), Type: float64
# - normalized_data_10
#   Shape: (13782150,), Type: float64
# - normalized_data_100
#   Shape: (13896950,), Type: float64
# - normalized_data_101
#   Shape: (13970019,), Type: float64
# - normalized_data_102
#   Shape: (13783233,), Type: float64
# - normalized_data_103
#   Shape: (13856191,), Type: float64
# - normalized_data_104
#   Shape: (13979851,), Type: float64
# - normalized_data_105
#   Shape: (13964276,), Type: float64
# - normalized_data_106
#   Shape: (13758919,), Type: float64
# - normalized_data_107
#   Shape: (13822880,), Type: float64
# - normalized_data_108
#   Shape: (13904279,), Type: float64
# - normalized_data_109
#   Shape: (13828810,), Type: float64
# - normalized_data_11
#   Shape: (13864790,), Type: float64
# - normalized_data_110
#   Shape: (13980940,), Type: float64
# - normalized_data_111
#   Shape: (13785868,), Type: float64
# - normalized_data_112
#   Shape: (13916100,), Type: float64
# - normalized_data_113
#   Shape: (13773842,), Type: float64
# - normalized_data_114
#   Shape: (13764725,), Type: float64
# - normalized_data_115
#   Shape: (13896663,), Type: float64
# - normalized_data_116
#   Shape: (13792986,), Type: float64
# - normalized_data_117
#   Shape: (13933409,), Type: float64
# - normalized_data_118
#   Shape: (13906695,), Type: float64
# - normalized_data_119
#   Shape: (13786421,), Type: float64
# - normalized_data_12
#   Shape: (13890248,), Type: float64
# - normalized_data_120
#   Shape: (13844049,), Type: float64
# - normalized_data_121
#   Shape: (13822846,), Type: float64
# - normalized_data_122
#   Shape: (13925478,), Type: float64
# - normalized_data_123
#   Shape: (13822041,), Type: float64
# - normalized_data_124
#   Shape: (13893832,), Type: float64
# - normalized_data_125
#   Shape: (13809607,), Type: float64
# - normalized_data_126
#   Shape: (13870546,), Type: float64
# - normalized_data_127
#   Shape: (13783783,), Type: float64
# - normalized_data_128
#   Shape: (13765440,), Type: float64
# - normalized_data_129
#   Shape: (13838269,), Type: float64
# - normalized_data_13
#   Shape: (13755324,), Type: float64
# - normalized_data_130
#   Shape: (13885897,), Type: float64
# - normalized_data_131
#   Shape: (13986008,), Type: float64
# - normalized_data_132
#   Shape: (13828314,), Type: float64
# - normalized_data_133
#   Shape: (13770692,), Type: float64
# - normalized_data_134
#   Shape: (14150429,), Type: float64
# - normalized_data_135
#   Shape: (13832600,), Type: float64
# - normalized_data_136
#   Shape: (13769911,), Type: float64
# - normalized_data_137
#   Shape: (13823239,), Type: float64
# - normalized_data_138
#   Shape: (13827766,), Type: float64
# - normalized_data_139
#   Shape: (13931849,), Type: float64
# - normalized_data_14
#   Shape: (13768109,), Type: float64
# - normalized_data_140
#   Shape: (13823828,), Type: float64
# - normalized_data_141
#   Shape: (13779192,), Type: float64
# - normalized_data_142
#   Shape: (13931744,), Type: float64
# - normalized_data_143
#   Shape: (13802156,), Type: float64
# - normalized_data_144
#   Shape: (13878048,), Type: float64
# - normalized_data_145
#   Shape: (13938485,), Type: float64
# - normalized_data_146
#   Shape: (13859229,), Type: float64
# - normalized_data_147
#   Shape: (13952806,), Type: float64
# - normalized_data_148
#   Shape: (13889947,), Type: float64
# - normalized_data_149
#   Shape: (13902404,), Type: float64
# - normalized_data_15
#   Shape: (13815911,), Type: float64
# - normalized_data_150
#   Shape: (13773231,), Type: float64
# - normalized_data_151
#   Shape: (13780116,), Type: float64
# - normalized_data_152
#   Shape: (13831969,), Type: float64
# - normalized_data_153
#   Shape: (13820288,), Type: float64
# - normalized_data_154
#   Shape: (13769882,), Type: float64
# - normalized_data_155
#   Shape: (13903373,), Type: float64
# - normalized_data_156
#   Shape: (13907541,), Type: float64
# - normalized_data_157
#   Shape: (13883764,), Type: float64
# - normalized_data_158
#   Shape: (13826916,), Type: float64
# - normalized_data_159
#   Shape: (13806536,), Type: float64
# - normalized_data_16
#   Shape: (13774840,), Type: float64
# - normalized_data_160
#   Shape: (13832867,), Type: float64
# - normalized_data_161
#   Shape: (13851512,), Type: float64
# - normalized_data_162
#   Shape: (13910707,), Type: float64
# - normalized_data_163
#   Shape: (13812316,), Type: float64
# - normalized_data_164
#   Shape: (13874101,), Type: float64
# - normalized_data_165
#   Shape: (13919489,), Type: float64
# - normalized_data_166
#   Shape: (13880565,), Type: float64
# - normalized_data_167
#   Shape: (13953068,), Type: float64
# - normalized_data_168
#   Shape: (13910426,), Type: float64
# - normalized_data_169
#   Shape: (13874535,), Type: float64
# - normalized_data_17
#   Shape: (13738363,), Type: float64
# - normalized_data_170
#   Shape: (13767660,), Type: float64
# - normalized_data_171
#   Shape: (13837600,), Type: float64
# - normalized_data_172
#   Shape: (13854960,), Type: float64
# - normalized_data_173
#   Shape: (13808949,), Type: float64
# - normalized_data_174
#   Shape: (13874500,), Type: float64
# - normalized_data_175
#   Shape: (13830211,), Type: float64
# - normalized_data_176
#   Shape: (13791587,), Type: float64
# - normalized_data_177
#   Shape: (13788013,), Type: float64
# - normalized_data_178
#   Shape: (13926565,), Type: float64
# - normalized_data_179
#   Shape: (13927232,), Type: float64
# - normalized_data_18
#   Shape: (13758339,), Type: float64
# - normalized_data_180
#   Shape: (13775886,), Type: float64
# - normalized_data_181
#   Shape: (13817907,), Type: float64
# - normalized_data_182
#   Shape: (13798154,), Type: float64
# - normalized_data_183
#   Shape: (13782271,), Type: float64
# - normalized_data_184
#   Shape: (13941063,), Type: float64
# - normalized_data_185
#   Shape: (13929528,), Type: float64
# - normalized_data_186
#   Shape: (14012971,), Type: float64
# - normalized_data_187
#   Shape: (13776970,), Type: float64
# - normalized_data_188
#   Shape: (13734001,), Type: float64
# - normalized_data_189
#   Shape: (13746085,), Type: float64
# - normalized_data_19
#   Shape: (13902557,), Type: float64
# - normalized_data_190
#   Shape: (13889008,), Type: float64
# - normalized_data_191
#   Shape: (13787903,), Type: float64
# - normalized_data_192
#   Shape: (13795583,), Type: float64
# - normalized_data_193
#   Shape: (13809641,), Type: float64
# - normalized_data_194
#   Shape: (13831115,), Type: float64
# - normalized_data_195
#   Shape: (13845645,), Type: float64
# - normalized_data_196
#   Shape: (13769912,), Type: float64
# - normalized_data_197
#   Shape: (13830919,), Type: float64
# - normalized_data_198
#   Shape: (13773816,), Type: float64
# - normalized_data_199
#   Shape: (13953119,), Type: float64
# - normalized_data_2
#   Shape: (13876315,), Type: float64
# - normalized_data_20
#   Shape: (13902921,), Type: float64
# - normalized_data_200
#   Shape: (13831409,), Type: float64
# - normalized_data_201
#   Shape: (13871476,), Type: float64
# - normalized_data_202
#   Shape: (13791118,), Type: float64
# - normalized_data_203
#   Shape: (13758814,), Type: float64
# - normalized_data_204
#   Shape: (13818826,), Type: float64
# - normalized_data_205
#   Shape: (13837970,), Type: float64
# - normalized_data_206
#   Shape: (13822410,), Type: float64
# - normalized_data_207
#   Shape: (13891323,), Type: float64
# - normalized_data_208
#   Shape: (14004712,), Type: float64
# - normalized_data_209
#   Shape: (13763197,), Type: float64
# - normalized_data_21
#   Shape: (13897314,), Type: float64
# - normalized_data_210
#   Shape: (13812459,), Type: float64
# - normalized_data_211
#   Shape: (13829598,), Type: float64
# - normalized_data_212
#   Shape: (13848053,), Type: float64
# - normalized_data_213
#   Shape: (13814508,), Type: float64
# - normalized_data_214
#   Shape: (13772376,), Type: float64
# - normalized_data_215
#   Shape: (13910040,), Type: float64
# - normalized_data_216
#   Shape: (13831206,), Type: float64
# - normalized_data_217
#   Shape: (13824571,), Type: float64
# - normalized_data_218
#   Shape: (13881555,), Type: float64
# - normalized_data_219
#   Shape: (13904674,), Type: float64
# - normalized_data_22
#   Shape: (13923534,), Type: float64
# - normalized_data_220
#   Shape: (13860623,), Type: float64
# - normalized_data_221
#   Shape: (13770451,), Type: float64
# - normalized_data_222
#   Shape: (13783564,), Type: float64
# - normalized_data_223
#   Shape: (13811304,), Type: float64
# - normalized_data_224
#   Shape: (13809285,), Type: float64
# - normalized_data_225
#   Shape: (13816500,), Type: float64
# - normalized_data_226
#   Shape: (13867018,), Type: float64
# - normalized_data_227
#   Shape: (13795697,), Type: float64
# - normalized_data_228
#   Shape: (13810765,), Type: float64
# - normalized_data_229
#   Shape: (13782070,), Type: float64
# - normalized_data_23
#   Shape: (12780677,), Type: float64
# - normalized_data_230
#   Shape: (13945102,), Type: float64
# - normalized_data_231
#   Shape: (13907754,), Type: float64
# - normalized_data_232
#   Shape: (13784516,), Type: float64
# - normalized_data_233
#   Shape: (13841479,), Type: float64
# - normalized_data_234
#   Shape: (13773515,), Type: float64
# - normalized_data_235
#   Shape: (13808303,), Type: float64
# - normalized_data_236
#   Shape: (13812772,), Type: float64
# - normalized_data_237
#   Shape: (13790731,), Type: float64
# - normalized_data_238
#   Shape: (13776249,), Type: float64
# - normalized_data_239
#   Shape: (9022210,), Type: float64
# - normalized_data_24
#   Shape: (13915040,), Type: float64
# - normalized_data_240
#   Shape: (13912651,), Type: float64
# - normalized_data_241
#   Shape: (13874771,), Type: float64
# - normalized_data_242
#   Shape: (13871355,), Type: float64
# - normalized_data_243
#   Shape: (13779632,), Type: float64
# - normalized_data_244
#   Shape: (13861278,), Type: float64
# - normalized_data_245
#   Shape: (13894463,), Type: float64
# - normalized_data_246
#   Shape: (13944133,), Type: float64
# - normalized_data_247
#   Shape: (13789290,), Type: float64
# - normalized_data_248
#   Shape: (13758573,), Type: float64
# - normalized_data_249
#   Shape: (13893214,), Type: float64
# - normalized_data_25
#   Shape: (13814029,), Type: float64
# - normalized_data_250
#   Shape: (13925445,), Type: float64
# - normalized_data_251
#   Shape: (13935110,), Type: float64
# - normalized_data_252
#   Shape: (13783694,), Type: float64
# - normalized_data_253
#   Shape: (13811401,), Type: float64
# - normalized_data_254
#   Shape: (13755776,), Type: float64
# - normalized_data_255
#   Shape: (13872301,), Type: float64
# - normalized_data_256
#   Shape: (13910481,), Type: float64
# - normalized_data_257
#   Shape: (13851628,), Type: float64
# - normalized_data_258
#   Shape: (13953028,), Type: float64
# - normalized_data_259
#   Shape: (13760637,), Type: float64
# - normalized_data_26
#   Shape: (13769688,), Type: float64
# - normalized_data_260
#   Shape: (13789864,), Type: float64
# - normalized_data_261
#   Shape: (13837779,), Type: float64
# - normalized_data_262
#   Shape: (13771362,), Type: float64
# - normalized_data_263
#   Shape: (13893567,), Type: float64
# - normalized_data_264
#   Shape: (13852054,), Type: float64
# - normalized_data_265
#   Shape: (13795171,), Type: float64
# - normalized_data_266
#   Shape: (13773033,), Type: float64
# - normalized_data_267
#   Shape: (13966584,), Type: float64
# - normalized_data_268
#   Shape: (13972928,), Type: float64
# - normalized_data_269
#   Shape: (13779825,), Type: float64
# - normalized_data_27
#   Shape: (13890969,), Type: float64
# - normalized_data_270
#   Shape: (13944640,), Type: float64
# - normalized_data_271
#   Shape: (13786703,), Type: float64
# - normalized_data_272
#   Shape: (13807303,), Type: float64
# - normalized_data_273
#   Shape: (13806121,), Type: float64
# - normalized_data_274
#   Shape: (13761062,), Type: float64
# - normalized_data_275
#   Shape: (13778054,), Type: float64
# - normalized_data_276
#   Shape: (13918869,), Type: float64
# - normalized_data_277
#   Shape: (13888024,), Type: float64
# - normalized_data_278
#   Shape: (13846386,), Type: float64
# - normalized_data_279
#   Shape: (13828862,), Type: float64
# - normalized_data_28
#   Shape: (13828943,), Type: float64
# - normalized_data_280
#   Shape: (13827367,), Type: float64
# - normalized_data_281
#   Shape: (13906524,), Type: float64
# - normalized_data_282
#   Shape: (13774261,), Type: float64
# - normalized_data_283
#   Shape: (13853454,), Type: float64
# - normalized_data_284
#   Shape: (13917943,), Type: float64
# - normalized_data_285
#   Shape: (13856244,), Type: float64
# - normalized_data_286
#   Shape: (13928682,), Type: float64
# - normalized_data_287
#   Shape: (13910928,), Type: float64
# - normalized_data_288
#   Shape: (14030069,), Type: float64
# - normalized_data_289
#   Shape: (13786322,), Type: float64
# - normalized_data_29
#   Shape: (13906366,), Type: float64
# - normalized_data_290
#   Shape: (13931062,), Type: float64
# - normalized_data_291
#   Shape: (13813306,), Type: float64
# - normalized_data_292
#   Shape: (13824374,), Type: float64
# - normalized_data_293
#   Shape: (13796538,), Type: float64
# - normalized_data_294
#   Shape: (13911630,), Type: float64
# - normalized_data_295
#   Shape: (13911283,), Type: float64
# - normalized_data_296
#   Shape: (13906570,), Type: float64
# - normalized_data_297
#   Shape: (13729123,), Type: float64
# - normalized_data_298
#   Shape: (13768356,), Type: float64
# - normalized_data_299
#   Shape: (13804441,), Type: float64
# - normalized_data_3
#   Shape: (13884856,), Type: float64
# - normalized_data_30
#   Shape: (13774369,), Type: float64
# - normalized_data_300
#   Shape: (13767191,), Type: float64
# - normalized_data_301
#   Shape: (13967837,), Type: float64
# - normalized_data_302
#   Shape: (13786784,), Type: float64
# - normalized_data_303
#   Shape: (13827729,), Type: float64
# - normalized_data_304
#   Shape: (13905482,), Type: float64
# - normalized_data_305
#   Shape: (13781795,), Type: float64
# - normalized_data_306
#   Shape: (13772930,), Type: float64
# - normalized_data_307
#   Shape: (13808042,), Type: float64
# - normalized_data_308
#   Shape: (13905937,), Type: float64
# - normalized_data_309
#   Shape: (13786830,), Type: float64
# - normalized_data_31
#   Shape: (13971388,), Type: float64
# - normalized_data_310
#   Shape: (13933436,), Type: float64
# - normalized_data_311
#   Shape: (13822282,), Type: float64
# - normalized_data_312
#   Shape: (13804647,), Type: float64
# - normalized_data_313
#   Shape: (13794313,), Type: float64
# - normalized_data_314
#   Shape: (13785495,), Type: float64
# - normalized_data_315
#   Shape: (13874963,), Type: float64
# - normalized_data_316
#   Shape: (13825026,), Type: float64
# - normalized_data_317
#   Shape: (13772450,), Type: float64
# - normalized_data_318
#   Shape: (13868085,), Type: float64
# - normalized_data_319
#   Shape: (13784677,), Type: float64
# - normalized_data_32
#   Shape: (13965802,), Type: float64
# - normalized_data_320
#   Shape: (13912824,), Type: float64
# - normalized_data_321
#   Shape: (13875417,), Type: float64
# - normalized_data_322
#   Shape: (13776372,), Type: float64
# - normalized_data_323
#   Shape: (13834952,), Type: float64
# - normalized_data_324
#   Shape: (13785576,), Type: float64
# - normalized_data_325
#   Shape: (13793151,), Type: float64
# - normalized_data_326
#   Shape: (13796474,), Type: float64
# - normalized_data_327
#   Shape: (13908910,), Type: float64
# - normalized_data_328
#   Shape: (13897339,), Type: float64
# - normalized_data_329
#   Shape: (13839095,), Type: float64
# - normalized_data_33
#   Shape: (13767094,), Type: float64
# - normalized_data_330
#   Shape: (13850760,), Type: float64
# - normalized_data_331
#   Shape: (13808508,), Type: float64
# - normalized_data_332
#   Shape: (13907172,), Type: float64
# - normalized_data_333
#   Shape: (13830035,), Type: float64
# - normalized_data_334
#   Shape: (13806361,), Type: float64
# - normalized_data_335
#   Shape: (13801924,), Type: float64
# - normalized_data_336
#   Shape: (13972142,), Type: float64
# - normalized_data_337
#   Shape: (13795365,), Type: float64
# - normalized_data_338
#   Shape: (13987245,), Type: float64
# - normalized_data_339
#   Shape: (13803546,), Type: float64
# - normalized_data_34
#   Shape: (13913590,), Type: float64
# - normalized_data_340
#   Shape: (13881924,), Type: float64
# - normalized_data_341
#   Shape: (13943017,), Type: float64
# - normalized_data_342
#   Shape: (13855949,), Type: float64
# - normalized_data_343
#   Shape: (13755670,), Type: float64
# - normalized_data_344
#   Shape: (13809030,), Type: float64
# - normalized_data_345
#   Shape: (13796077,), Type: float64
# - normalized_data_346
#   Shape: (13921771,), Type: float64
# - normalized_data_347
#   Shape: (13791293,), Type: float64
# - normalized_data_348
#   Shape: (13778061,), Type: float64
# - normalized_data_349
#   Shape: (13767991,), Type: float64
# - normalized_data_35
#   Shape: (13813070,), Type: float64
# - normalized_data_350
#   Shape: (13906908,), Type: float64
# - normalized_data_351
#   Shape: (13768445,), Type: float64
# - normalized_data_352
#   Shape: (13925668,), Type: float64
# - normalized_data_353
#   Shape: (13921892,), Type: float64
# - normalized_data_354
#   Shape: (13922427,), Type: float64
# - normalized_data_355
#   Shape: (13914733,), Type: float64
# - normalized_data_356
#   Shape: (13932108,), Type: float64
# - normalized_data_357
#   Shape: (13881982,), Type: float64
# - normalized_data_358
#   Shape: (13807267,), Type: float64
# - normalized_data_359
#   Shape: (13990446,), Type: float64
# - normalized_data_36
#   Shape: (13785130,), Type: float64
# - normalized_data_360
#   Shape: (13781796,), Type: float64
# - normalized_data_361
#   Shape: (13918837,), Type: float64
# - normalized_data_362
#   Shape: (13773977,), Type: float64
# - normalized_data_363
#   Shape: (13870242,), Type: float64
# - normalized_data_364
#   Shape: (13810086,), Type: float64
# - normalized_data_365
#   Shape: (13901818,), Type: float64
# - normalized_data_366
#   Shape: (13774892,), Type: float64
# - normalized_data_367
#   Shape: (13769529,), Type: float64
# - normalized_data_368
#   Shape: (13837189,), Type: float64
# - normalized_data_369
#   Shape: (13839235,), Type: float64
# - normalized_data_37
#   Shape: (13907462,), Type: float64
# - normalized_data_370
#   Shape: (13880417,), Type: float64
# - normalized_data_371
#   Shape: (13835569,), Type: float64
# - normalized_data_372
#   Shape: (13799672,), Type: float64
# - normalized_data_373
#   Shape: (13904147,), Type: float64
# - normalized_data_374
#   Shape: (13883512,), Type: float64
# - normalized_data_375
#   Shape: (13857531,), Type: float64
# - normalized_data_376
#   Shape: (13913844,), Type: float64
# - normalized_data_377
#   Shape: (13948257,), Type: float64
# - normalized_data_378
#   Shape: (13927868,), Type: float64
# - normalized_data_379
#   Shape: (13856809,), Type: float64
# - normalized_data_38
#   Shape: (13825910,), Type: float64
# - normalized_data_380
#   Shape: (13842543,), Type: float64
# - normalized_data_381
#   Shape: (13841191,), Type: float64
# - normalized_data_382
#   Shape: (13938926,), Type: float64
# - normalized_data_383
#   Shape: (13825687,), Type: float64
# - normalized_data_384
#   Shape: (13890208,), Type: float64
# - normalized_data_385
#   Shape: (13882497,), Type: float64
# - normalized_data_386
#   Shape: (13908129,), Type: float64
# - normalized_data_387
#   Shape: (13731065,), Type: float64
# - normalized_data_388
#   Shape: (13800037,), Type: float64
# - normalized_data_389
#   Shape: (13930554,), Type: float64
# - normalized_data_39
#   Shape: (13821699,), Type: float64
# - normalized_data_390
#   Shape: (13820493,), Type: float64
# - normalized_data_391
#   Shape: (13787264,), Type: float64
# - normalized_data_392
#   Shape: (13782608,), Type: float64
# - normalized_data_393
#   Shape: (13786176,), Type: float64
# - normalized_data_394
#   Shape: (13775834,), Type: float64
# - normalized_data_395
#   Shape: (13813589,), Type: float64
# - normalized_data_396
#   Shape: (13906895,), Type: float64
# - normalized_data_397
#   Shape: (13840301,), Type: float64
# - normalized_data_398
#   Shape: (13856963,), Type: float64
# - normalized_data_399
#   Shape: (13768209,), Type: float64
# - normalized_data_4
#   Shape: (13892215,), Type: float64
# - normalized_data_40
#   Shape: (13803273,), Type: float64
# - normalized_data_400
#   Shape: (13885023,), Type: float64
# - normalized_data_401
#   Shape: (13904040,), Type: float64
# - normalized_data_402
#   Shape: (13784612,), Type: float64
# - normalized_data_403
#   Shape: (13769206,), Type: float64
# - normalized_data_404
#   Shape: (13937137,), Type: float64
# - normalized_data_405
#   Shape: (13895672,), Type: float64
# - normalized_data_406
#   Shape: (13872596,), Type: float64
# - normalized_data_407
#   Shape: (13788512,), Type: float64
# - normalized_data_408
#   Shape: (13904935,), Type: float64
# - normalized_data_409
#   Shape: (13900380,), Type: float64
# - normalized_data_41
#   Shape: (13881305,), Type: float64
# - normalized_data_410
#   Shape: (13941864,), Type: float64
# - normalized_data_411
#   Shape: (13832621,), Type: float64
# - normalized_data_412
#   Shape: (13919303,), Type: float64
# - normalized_data_413
#   Shape: (13907628,), Type: float64
# - normalized_data_414
#   Shape: (13769712,), Type: float64
# - normalized_data_415
#   Shape: (13828983,), Type: float64
# - normalized_data_416
#   Shape: (13924204,), Type: float64
# - normalized_data_417
#   Shape: (13852989,), Type: float64
# - normalized_data_418
#   Shape: (13800919,), Type: float64
# - normalized_data_419
#   Shape: (13912622,), Type: float64
# - normalized_data_42
#   Shape: (13779491,), Type: float64
# - normalized_data_420
#   Shape: (13817450,), Type: float64
# - normalized_data_421
#   Shape: (13903727,), Type: float64
# - normalized_data_422
#   Shape: (13763753,), Type: float64
# - normalized_data_423
#   Shape: (13837991,), Type: float64
# - normalized_data_424
#   Shape: (13861329,), Type: float64
# - normalized_data_425
#   Shape: (13768612,), Type: float64
# - normalized_data_426
#   Shape: (13880405,), Type: float64
# - normalized_data_427
#   Shape: (13871802,), Type: float64
# - normalized_data_428
#   Shape: (14011571,), Type: float64
# - normalized_data_429
#   Shape: (13789107,), Type: float64
# - normalized_data_43
#   Shape: (13898223,), Type: float64
# - normalized_data_430
#   Shape: (13785312,), Type: float64
# - normalized_data_431
#   Shape: (13816869,), Type: float64
# - normalized_data_432
#   Shape: (13828137,), Type: float64
# - normalized_data_433
#   Shape: (13818423,), Type: float64
# - normalized_data_434
#   Shape: (13920905,), Type: float64
# - normalized_data_435
#   Shape: (13797910,), Type: float64
# - normalized_data_436
#   Shape: (13864792,), Type: float64
# - normalized_data_437
#   Shape: (13865708,), Type: float64
# - normalized_data_438
#   Shape: (13800809,), Type: float64
# - normalized_data_439
#   Shape: (13796416,), Type: float64
# - normalized_data_44
#   Shape: (13773655,), Type: float64
# - normalized_data_440
#   Shape: (13865567,), Type: float64
# - normalized_data_441
#   Shape: (13904703,), Type: float64
# - normalized_data_442
#   Shape: (13793979,), Type: float64
# - normalized_data_443
#   Shape: (13887655,), Type: float64
# - normalized_data_444
#   Shape: (13779161,), Type: float64
# - normalized_data_445
#   Shape: (13920032,), Type: float64
# - normalized_data_446
#   Shape: (13822484,), Type: float64
# - normalized_data_447
#   Shape: (13766160,), Type: float64
# - normalized_data_448
#   Shape: (13837890,), Type: float64
# - normalized_data_449
#   Shape: (13905319,), Type: float64
# - normalized_data_45
#   Shape: (13818024,), Type: float64
# - normalized_data_450
#   Shape: (13782953,), Type: float64
# - normalized_data_451
#   Shape: (13758453,), Type: float64
# - normalized_data_452
#   Shape: (13882089,), Type: float64
# - normalized_data_453
#   Shape: (13789757,), Type: float64
# - normalized_data_454
#   Shape: (13825206,), Type: float64
# - normalized_data_455
#   Shape: (13884632,), Type: float64
# - normalized_data_456
#   Shape: (13788437,), Type: float64
# - normalized_data_457
#   Shape: (13791218,), Type: float64
# - normalized_data_458
#   Shape: (13726539,), Type: float64
# - normalized_data_459
#   Shape: (13805630,), Type: float64
# - normalized_data_46
#   Shape: (13884132,), Type: float64
# - normalized_data_460
#   Shape: (13801165,), Type: float64
# - normalized_data_461
#   Shape: (13818957,), Type: float64
# - normalized_data_462
#   Shape: (13960291,), Type: float64
# - normalized_data_463
#   Shape: (13772132,), Type: float64
# - normalized_data_464
#   Shape: (13766466,), Type: float64
# - normalized_data_465
#   Shape: (13925508,), Type: float64
# - normalized_data_466
#   Shape: (13862817,), Type: float64
# - normalized_data_467
#   Shape: (13888587,), Type: float64
# - normalized_data_468
#   Shape: (13771291,), Type: float64
# - normalized_data_469
#   Shape: (13823460,), Type: float64
# - normalized_data_47
#   Shape: (13729762,), Type: float64
# - normalized_data_470
#   Shape: (13837744,), Type: float64
# - normalized_data_471
#   Shape: (13916496,), Type: float64
# - normalized_data_472
#   Shape: (13771968,), Type: float64
# - normalized_data_473
#   Shape: (13814289,), Type: float64
# - normalized_data_474
#   Shape: (13787843,), Type: float64
# - normalized_data_475
#   Shape: (13925529,), Type: float64
# - normalized_data_476
#   Shape: (13970969,), Type: float64
# - normalized_data_477
#   Shape: (13804969,), Type: float64
# - normalized_data_478
#   Shape: (13856402,), Type: float64
# - normalized_data_479
#   Shape: (13761674,), Type: float64
# - normalized_data_48
#   Shape: (13887212,), Type: float64
# - normalized_data_480
#   Shape: (13903193,), Type: float64
# - normalized_data_481
#   Shape: (13763949,), Type: float64
# - normalized_data_482
#   Shape: (13923854,), Type: float64
# - normalized_data_483
#   Shape: (13880090,), Type: float64
# - normalized_data_484
#   Shape: (13767299,), Type: float64
# - normalized_data_485
#   Shape: (13890866,), Type: float64
# - normalized_data_486
#   Shape: (13782238,), Type: float64
# - normalized_data_487
#   Shape: (13770833,), Type: float64
# - normalized_data_488
#   Shape: (13765749,), Type: float64
# - normalized_data_489
#   Shape: (13902798,), Type: float64
# - normalized_data_49
#   Shape: (13804768,), Type: float64
# - normalized_data_490
#   Shape: (13823565,), Type: float64
# - normalized_data_491
#   Shape: (13769746,), Type: float64
# - normalized_data_492
#   Shape: (13873115,), Type: float64
# - normalized_data_493
#   Shape: (11238797,), Type: float64
# - normalized_data_494
#   Shape: (13788690,), Type: float64
# - normalized_data_495
#   Shape: (13905196,), Type: float64
# - normalized_data_496
#   Shape: (13787155,), Type: float64
# - normalized_data_497
#   Shape: (13840260,), Type: float64
# - normalized_data_498
#   Shape: (13894224,), Type: float64
# - normalized_data_499
#   Shape: (13782304,), Type: float64
# - normalized_data_5
#   Shape: (13883484,), Type: float64
# - normalized_data_50
#   Shape: (13787938,), Type: float64
# - normalized_data_51
#   Shape: (13779084,), Type: float64
# - normalized_data_52
#   Shape: (13778375,), Type: float64
# - normalized_data_53
#   Shape: (13745381,), Type: float64
# - normalized_data_54
#   Shape: (13835412,), Type: float64
# - normalized_data_55
#   Shape: (13858936,), Type: float64
# - normalized_data_56
#   Shape: (13926881,), Type: float64
# - normalized_data_57
#   Shape: (13808702,), Type: float64
# - normalized_data_58
#   Shape: (13771472,), Type: float64
# - normalized_data_59
#   Shape: (13913723,), Type: float64
# - normalized_data_6
#   Shape: (13776051,), Type: float64
# - normalized_data_60
#   Shape: (13814582,), Type: float64
# - normalized_data_61
#   Shape: (13874771,), Type: float64
# - normalized_data_62
#   Shape: (13895640,), Type: float64
# - normalized_data_63
#   Shape: (13930037,), Type: float64
# - normalized_data_64
#   Shape: (13913783,), Type: float64
# - normalized_data_65
#   Shape: (13918790,), Type: float64
# - normalized_data_66
#   Shape: (13806718,), Type: float64
# - normalized_data_67
#   Shape: (13797908,), Type: float64
# - normalized_data_68
#   Shape: (13820714,), Type: float64
# - normalized_data_69
#   Shape: (13769844,), Type: float64
# - normalized_data_7
#   Shape: (13829829,), Type: float64
# - normalized_data_70
#   Shape: (13771332,), Type: float64
# - normalized_data_71
#   Shape: (13718059,), Type: float64
# - normalized_data_72
#   Shape: (13957249,), Type: float64
# - normalized_data_73
#   Shape: (13846253,), Type: float64
# - normalized_data_74
#   Shape: (13836668,), Type: float64
# - normalized_data_75
#   Shape: (13771333,), Type: float64
# - normalized_data_76
#   Shape: (13822891,), Type: float64
# - normalized_data_77
#   Shape: (13899114,), Type: float64
# - normalized_data_78
#   Shape: (13785390,), Type: float64
# - normalized_data_79
#   Shape: (13889179,), Type: float64
# - normalized_data_8
#   Shape: (13895864,), Type: float64
# - normalized_data_80
#   Shape: (14011810,), Type: float64
# - normalized_data_81
#   Shape: (13775282,), Type: float64
# - normalized_data_82
#   Shape: (13821278,), Type: float64
# - normalized_data_83
#   Shape: (13932744,), Type: float64
# - normalized_data_84
#   Shape: (13900187,), Type: float64
# - normalized_data_85
#   Shape: (13775441,), Type: float64
# - normalized_data_86
#   Shape: (13909876,), Type: float64
# - normalized_data_87
#   Shape: (13908147,), Type: float64
# - normalized_data_88
#   Shape: (13930854,), Type: float64
# - normalized_data_89
#   Shape: (13809142,), Type: float64
# - normalized_data_9
#   Shape: (13888895,), Type: float64
# - normalized_data_90
#   Shape: (13800713,), Type: float64
# - normalized_data_91
#   Shape: (13823863,), Type: float64
# - normalized_data_92
#   Shape: (13783080,), Type: float64
# - normalized_data_93
#   Shape: (13798097,), Type: float64
# - normalized_data_94
#   Shape: (13843810,), Type: float64
# - normalized_data_95
#   Shape: (13770026,), Type: float64
# - normalized_data_96
#   Shape: (13873151,), Type: float64
# - normalized_data_97
#   Shape: (13891967,), Type: float64
# - normalized_data_98
#   Shape: (13781877,), Type: float64
# - normalized_data_99
#   Shape: (13791020,), Type: float64

# %% [markdown]
# Task: Calculate the 99th percentile pixel intensity for each AIA wavelength from the given H5 files. This will help identify the threshold values for extreme brightness in the solar images across different wavelengths.

# %%
h5_files[1]
# Out:
# PosixPath('/mnt/data/Normalized_Data/aia171_batch2_data_20250710_050922.h5')

# %%
with h5py.File(h5_files[0], 'r') as f:
    # Print the structure
    print("File structure:")


    def print_structure(name, obj):
        if isinstance(obj, h5py.Dataset):
            print(f"{name}: shape={obj.shape}, dtype={obj.dtype}")


    f.visititems(print_structure)

    # Load the first dataset found
    first_dataset = next(iter(f.values()))
    data = first_dataset[:]
    print("\nSample data:")
    print(data[:5])  # Show first 5 elements
# Out:
# File structure:
# normalized_data_0: shape=(13866348,), dtype=float64
# normalized_data_1: shape=(13935107,), dtype=float64
# normalized_data_10: shape=(13782150,), dtype=float64
# normalized_data_100: shape=(13896950,), dtype=float64
# normalized_data_101: shape=(13970019,), dtype=float64
# normalized_data_102: shape=(13783233,), dtype=float64
# normalized_data_103: shape=(13856191,), dtype=float64
# normalized_data_104: shape=(13979851,), dtype=float64
# normalized_data_105: shape=(13964276,), dtype=float64
# normalized_data_106: shape=(13758919,), dtype=float64
# normalized_data_107: shape=(13822880,), dtype=float64
# normalized_data_108: shape=(13904279,), dtype=float64
# normalized_data_109: shape=(13828810,), dtype=float64
# normalized_data_11: shape=(13864790,), dtype=float64
# normalized_data_110: shape=(13980940,), dtype=float64
# normalized_data_111: shape=(13785868,), dtype=float64
# normalized_data_112: shape=(13916100,), dtype=float64
# normalized_data_113: shape=(13773842,), dtype=float64
# normalized_data_114: shape=(13764725,), dtype=float64
# normalized_data_115: shape=(13896663,), dtype=float64
# normalized_data_116: shape=(13792986,), dtype=float64
# normalized_data_117: shape=(13933409,), dtype=float64
# normalized_data_118: shape=(13906695,), dtype=float64
# normalized_data_119: shape=(13786421,), dtype=float64
# normalized_data_12: shape=(13890248,), dtype=float64
# normalized_data_120: shape=(13844049,), dtype=float64
# normalized_data_121: shape=(13822846,), dtype=float64
# normalized_data_122: shape=(13925478,), dtype=float64
# normalized_data_123: shape=(13822041,), dtype=float64
# normalized_data_124: shape=(13893832,), dtype=float64
# normalized_data_125: shape=(13809607,), dtype=float64
# normalized_data_126: shape=(13870546,), dtype=float64
# normalized_data_127: shape=(13783783,), dtype=float64
# normalized_data_128: shape=(13765440,), dtype=float64
# normalized_data_129: shape=(13838269,), dtype=float64
# normalized_data_13: shape=(13755324,), dtype=float64
# normalized_data_130: shape=(13885897,), dtype=float64
# normalized_data_131: shape=(13986008,), dtype=float64
# normalized_data_132: shape=(13828314,), dtype=float64
# normalized_data_133: shape=(13770692,), dtype=float64
# normalized_data_134: shape=(14150429,), dtype=float64
# normalized_data_135: shape=(13832600,), dtype=float64
# normalized_data_136: shape=(13769911,), dtype=float64
# normalized_data_137: shape=(13823239,), dtype=float64
# normalized_data_138: shape=(13827766,), dtype=float64
# normalized_data_139: shape=(13931849,), dtype=float64
# normalized_data_14: shape=(13768109,), dtype=float64
# normalized_data_140: shape=(13823828,), dtype=float64
# normalized_data_141: shape=(13779192,), dtype=float64
# normalized_data_142: shape=(13931744,), dtype=float64
# normalized_data_143: shape=(13802156,), dtype=float64
# normalized_data_144: shape=(13878048,), dtype=float64
# normalized_data_145: shape=(13938485,), dtype=float64
# normalized_data_146: shape=(13859229,), dtype=float64
# normalized_data_147: shape=(13952806,), dtype=float64
# normalized_data_148: shape=(13889947,), dtype=float64
# normalized_data_149: shape=(13902404,), dtype=float64
# normalized_data_15: shape=(13815911,), dtype=float64
# normalized_data_150: shape=(13773231,), dtype=float64
# normalized_data_151: shape=(13780116,), dtype=float64
# normalized_data_152: shape=(13831969,), dtype=float64
# normalized_data_153: shape=(13820288,), dtype=float64
# normalized_data_154: shape=(13769882,), dtype=float64
# normalized_data_155: shape=(13903373,), dtype=float64
# normalized_data_156: shape=(13907541,), dtype=float64
# normalized_data_157: shape=(13883764,), dtype=float64
# normalized_data_158: shape=(13826916,), dtype=float64
# normalized_data_159: shape=(13806536,), dtype=float64
# normalized_data_16: shape=(13774840,), dtype=float64
# normalized_data_160: shape=(13832867,), dtype=float64
# normalized_data_161: shape=(13851512,), dtype=float64
# normalized_data_162: shape=(13910707,), dtype=float64
# normalized_data_163: shape=(13812316,), dtype=float64
# normalized_data_164: shape=(13874101,), dtype=float64
# normalized_data_165: shape=(13919489,), dtype=float64
# normalized_data_166: shape=(13880565,), dtype=float64
# normalized_data_167: shape=(13953068,), dtype=float64
# normalized_data_168: shape=(13910426,), dtype=float64
# normalized_data_169: shape=(13874535,), dtype=float64
# normalized_data_17: shape=(13738363,), dtype=float64
# normalized_data_170: shape=(13767660,), dtype=float64
# normalized_data_171: shape=(13837600,), dtype=float64
# normalized_data_172: shape=(13854960,), dtype=float64
# normalized_data_173: shape=(13808949,), dtype=float64
# normalized_data_174: shape=(13874500,), dtype=float64
# normalized_data_175: shape=(13830211,), dtype=float64
# normalized_data_176: shape=(13791587,), dtype=float64
# normalized_data_177: shape=(13788013,), dtype=float64
# normalized_data_178: shape=(13926565,), dtype=float64
# normalized_data_179: shape=(13927232,), dtype=float64
# normalized_data_18: shape=(13758339,), dtype=float64
# normalized_data_180: shape=(13775886,), dtype=float64
# normalized_data_181: shape=(13817907,), dtype=float64
# normalized_data_182: shape=(13798154,), dtype=float64
# normalized_data_183: shape=(13782271,), dtype=float64
# normalized_data_184: shape=(13941063,), dtype=float64
# normalized_data_185: shape=(13929528,), dtype=float64
# normalized_data_186: shape=(14012971,), dtype=float64
# normalized_data_187: shape=(13776970,), dtype=float64
# normalized_data_188: shape=(13734001,), dtype=float64
# normalized_data_189: shape=(13746085,), dtype=float64
# normalized_data_19: shape=(13902557,), dtype=float64
# normalized_data_190: shape=(13889008,), dtype=float64
# normalized_data_191: shape=(13787903,), dtype=float64
# normalized_data_192: shape=(13795583,), dtype=float64
# normalized_data_193: shape=(13809641,), dtype=float64
# normalized_data_194: shape=(13831115,), dtype=float64
# normalized_data_195: shape=(13845645,), dtype=float64
# normalized_data_196: shape=(13769912,), dtype=float64
# normalized_data_197: shape=(13830919,), dtype=float64
# normalized_data_198: shape=(13773816,), dtype=float64
# normalized_data_199: shape=(13953119,), dtype=float64
# normalized_data_2: shape=(13876315,), dtype=float64
# normalized_data_20: shape=(13902921,), dtype=float64
# normalized_data_200: shape=(13831409,), dtype=float64
# normalized_data_201: shape=(13871476,), dtype=float64
# normalized_data_202: shape=(13791118,), dtype=float64
# normalized_data_203: shape=(13758814,), dtype=float64
# normalized_data_204: shape=(13818826,), dtype=float64
# normalized_data_205: shape=(13837970,), dtype=float64
# normalized_data_206: shape=(13822410,), dtype=float64
# normalized_data_207: shape=(13891323,), dtype=float64
# normalized_data_208: shape=(14004712,), dtype=float64
# normalized_data_209: shape=(13763197,), dtype=float64
# normalized_data_21: shape=(13897314,), dtype=float64
# normalized_data_210: shape=(13812459,), dtype=float64
# normalized_data_211: shape=(13829598,), dtype=float64
# normalized_data_212: shape=(13848053,), dtype=float64
# normalized_data_213: shape=(13814508,), dtype=float64
# normalized_data_214: shape=(13772376,), dtype=float64
# normalized_data_215: shape=(13910040,), dtype=float64
# normalized_data_216: shape=(13831206,), dtype=float64
# normalized_data_217: shape=(13824571,), dtype=float64
# normalized_data_218: shape=(13881555,), dtype=float64
# normalized_data_219: shape=(13904674,), dtype=float64
# normalized_data_22: shape=(13923534,), dtype=float64
# normalized_data_220: shape=(13860623,), dtype=float64
# normalized_data_221: shape=(13770451,), dtype=float64
# normalized_data_222: shape=(13783564,), dtype=float64
# normalized_data_223: shape=(13811304,), dtype=float64
# normalized_data_224: shape=(13809285,), dtype=float64
# normalized_data_225: shape=(13816500,), dtype=float64
# normalized_data_226: shape=(13867018,), dtype=float64
# normalized_data_227: shape=(13795697,), dtype=float64
# normalized_data_228: shape=(13810765,), dtype=float64
# normalized_data_229: shape=(13782070,), dtype=float64
# normalized_data_23: shape=(12780677,), dtype=float64
# normalized_data_230: shape=(13945102,), dtype=float64
# normalized_data_231: shape=(13907754,), dtype=float64
# normalized_data_232: shape=(13784516,), dtype=float64
# normalized_data_233: shape=(13841479,), dtype=float64
# normalized_data_234: shape=(13773515,), dtype=float64
# normalized_data_235: shape=(13808303,), dtype=float64
# normalized_data_236: shape=(13812772,), dtype=float64
# normalized_data_237: shape=(13790731,), dtype=float64
# normalized_data_238: shape=(13776249,), dtype=float64
# normalized_data_239: shape=(9022210,), dtype=float64
# normalized_data_24: shape=(13915040,), dtype=float64
# normalized_data_240: shape=(13912651,), dtype=float64
# normalized_data_241: shape=(13874771,), dtype=float64
# normalized_data_242: shape=(13871355,), dtype=float64
# normalized_data_243: shape=(13779632,), dtype=float64
# normalized_data_244: shape=(13861278,), dtype=float64
# normalized_data_245: shape=(13894463,), dtype=float64
# normalized_data_246: shape=(13944133,), dtype=float64
# normalized_data_247: shape=(13789290,), dtype=float64
# normalized_data_248: shape=(13758573,), dtype=float64
# normalized_data_249: shape=(13893214,), dtype=float64
# normalized_data_25: shape=(13814029,), dtype=float64
# normalized_data_250: shape=(13925445,), dtype=float64
# normalized_data_251: shape=(13935110,), dtype=float64
# normalized_data_252: shape=(13783694,), dtype=float64
# normalized_data_253: shape=(13811401,), dtype=float64
# normalized_data_254: shape=(13755776,), dtype=float64
# normalized_data_255: shape=(13872301,), dtype=float64
# normalized_data_256: shape=(13910481,), dtype=float64
# normalized_data_257: shape=(13851628,), dtype=float64
# normalized_data_258: shape=(13953028,), dtype=float64
# normalized_data_259: shape=(13760637,), dtype=float64
# normalized_data_26: shape=(13769688,), dtype=float64
# normalized_data_260: shape=(13789864,), dtype=float64
# normalized_data_261: shape=(13837779,), dtype=float64
# normalized_data_262: shape=(13771362,), dtype=float64
# normalized_data_263: shape=(13893567,), dtype=float64
# normalized_data_264: shape=(13852054,), dtype=float64
# normalized_data_265: shape=(13795171,), dtype=float64
# normalized_data_266: shape=(13773033,), dtype=float64
# normalized_data_267: shape=(13966584,), dtype=float64
# normalized_data_268: shape=(13972928,), dtype=float64
# normalized_data_269: shape=(13779825,), dtype=float64
# normalized_data_27: shape=(13890969,), dtype=float64
# normalized_data_270: shape=(13944640,), dtype=float64
# normalized_data_271: shape=(13786703,), dtype=float64
# normalized_data_272: shape=(13807303,), dtype=float64
# normalized_data_273: shape=(13806121,), dtype=float64
# normalized_data_274: shape=(13761062,), dtype=float64
# normalized_data_275: shape=(13778054,), dtype=float64
# normalized_data_276: shape=(13918869,), dtype=float64
# normalized_data_277: shape=(13888024,), dtype=float64
# normalized_data_278: shape=(13846386,), dtype=float64
# normalized_data_279: shape=(13828862,), dtype=float64
# normalized_data_28: shape=(13828943,), dtype=float64
# normalized_data_280: shape=(13827367,), dtype=float64
# normalized_data_281: shape=(13906524,), dtype=float64
# normalized_data_282: shape=(13774261,), dtype=float64
# normalized_data_283: shape=(13853454,), dtype=float64
# normalized_data_284: shape=(13917943,), dtype=float64
# normalized_data_285: shape=(13856244,), dtype=float64
# normalized_data_286: shape=(13928682,), dtype=float64
# normalized_data_287: shape=(13910928,), dtype=float64
# normalized_data_288: shape=(14030069,), dtype=float64
# normalized_data_289: shape=(13786322,), dtype=float64
# normalized_data_29: shape=(13906366,), dtype=float64
# normalized_data_290: shape=(13931062,), dtype=float64
# normalized_data_291: shape=(13813306,), dtype=float64
# normalized_data_292: shape=(13824374,), dtype=float64
# normalized_data_293: shape=(13796538,), dtype=float64
# normalized_data_294: shape=(13911630,), dtype=float64
# normalized_data_295: shape=(13911283,), dtype=float64
# normalized_data_296: shape=(13906570,), dtype=float64
# normalized_data_297: shape=(13729123,), dtype=float64
# normalized_data_298: shape=(13768356,), dtype=float64
# normalized_data_299: shape=(13804441,), dtype=float64
# normalized_data_3: shape=(13884856,), dtype=float64
# normalized_data_30: shape=(13774369,), dtype=float64
# normalized_data_300: shape=(13767191,), dtype=float64
# normalized_data_301: shape=(13967837,), dtype=float64
# normalized_data_302: shape=(13786784,), dtype=float64
# normalized_data_303: shape=(13827729,), dtype=float64
# normalized_data_304: shape=(13905482,), dtype=float64
# normalized_data_305: shape=(13781795,), dtype=float64
# normalized_data_306: shape=(13772930,), dtype=float64
# normalized_data_307: shape=(13808042,), dtype=float64
# normalized_data_308: shape=(13905937,), dtype=float64
# normalized_data_309: shape=(13786830,), dtype=float64
# normalized_data_31: shape=(13971388,), dtype=float64
# normalized_data_310: shape=(13933436,), dtype=float64
# normalized_data_311: shape=(13822282,), dtype=float64
# normalized_data_312: shape=(13804647,), dtype=float64
# normalized_data_313: shape=(13794313,), dtype=float64
# normalized_data_314: shape=(13785495,), dtype=float64
# normalized_data_315: shape=(13874963,), dtype=float64
# normalized_data_316: shape=(13825026,), dtype=float64
# normalized_data_317: shape=(13772450,), dtype=float64
# normalized_data_318: shape=(13868085,), dtype=float64
# normalized_data_319: shape=(13784677,), dtype=float64
# normalized_data_32: shape=(13965802,), dtype=float64
# normalized_data_320: shape=(13912824,), dtype=float64
# normalized_data_321: shape=(13875417,), dtype=float64
# normalized_data_322: shape=(13776372,), dtype=float64
# normalized_data_323: shape=(13834952,), dtype=float64
# normalized_data_324: shape=(13785576,), dtype=float64
# normalized_data_325: shape=(13793151,), dtype=float64
# normalized_data_326: shape=(13796474,), dtype=float64
# normalized_data_327: shape=(13908910,), dtype=float64
# normalized_data_328: shape=(13897339,), dtype=float64
# normalized_data_329: shape=(13839095,), dtype=float64
# normalized_data_33: shape=(13767094,), dtype=float64
# normalized_data_330: shape=(13850760,), dtype=float64
# normalized_data_331: shape=(13808508,), dtype=float64
# normalized_data_332: shape=(13907172,), dtype=float64
# normalized_data_333: shape=(13830035,), dtype=float64
# normalized_data_334: shape=(13806361,), dtype=float64
# normalized_data_335: shape=(13801924,), dtype=float64
# normalized_data_336: shape=(13972142,), dtype=float64
# normalized_data_337: shape=(13795365,), dtype=float64
# normalized_data_338: shape=(13987245,), dtype=float64
# normalized_data_339: shape=(13803546,), dtype=float64
# normalized_data_34: shape=(13913590,), dtype=float64
# normalized_data_340: shape=(13881924,), dtype=float64
# normalized_data_341: shape=(13943017,), dtype=float64
# normalized_data_342: shape=(13855949,), dtype=float64
# normalized_data_343: shape=(13755670,), dtype=float64
# normalized_data_344: shape=(13809030,), dtype=float64
# normalized_data_345: shape=(13796077,), dtype=float64
# normalized_data_346: shape=(13921771,), dtype=float64
# normalized_data_347: shape=(13791293,), dtype=float64
# normalized_data_348: shape=(13778061,), dtype=float64
# normalized_data_349: shape=(13767991,), dtype=float64
# normalized_data_35: shape=(13813070,), dtype=float64
# normalized_data_350: shape=(13906908,), dtype=float64
# normalized_data_351: shape=(13768445,), dtype=float64
# normalized_data_352: shape=(13925668,), dtype=float64
# normalized_data_353: shape=(13921892,), dtype=float64
# normalized_data_354: shape=(13922427,), dtype=float64
# normalized_data_355: shape=(13914733,), dtype=float64
# normalized_data_356: shape=(13932108,), dtype=float64
# normalized_data_357: shape=(13881982,), dtype=float64
# normalized_data_358: shape=(13807267,), dtype=float64
# normalized_data_359: shape=(13990446,), dtype=float64
# normalized_data_36: shape=(13785130,), dtype=float64
# normalized_data_360: shape=(13781796,), dtype=float64
# normalized_data_361: shape=(13918837,), dtype=float64
# normalized_data_362: shape=(13773977,), dtype=float64
# normalized_data_363: shape=(13870242,), dtype=float64
# normalized_data_364: shape=(13810086,), dtype=float64
# normalized_data_365: shape=(13901818,), dtype=float64
# normalized_data_366: shape=(13774892,), dtype=float64
# normalized_data_367: shape=(13769529,), dtype=float64
# normalized_data_368: shape=(13837189,), dtype=float64
# normalized_data_369: shape=(13839235,), dtype=float64
# normalized_data_37: shape=(13907462,), dtype=float64
# normalized_data_370: shape=(13880417,), dtype=float64
# normalized_data_371: shape=(13835569,), dtype=float64
# normalized_data_372: shape=(13799672,), dtype=float64
# normalized_data_373: shape=(13904147,), dtype=float64
# normalized_data_374: shape=(13883512,), dtype=float64
# normalized_data_375: shape=(13857531,), dtype=float64
# normalized_data_376: shape=(13913844,), dtype=float64
# normalized_data_377: shape=(13948257,), dtype=float64
# normalized_data_378: shape=(13927868,), dtype=float64
# normalized_data_379: shape=(13856809,), dtype=float64
# normalized_data_38: shape=(13825910,), dtype=float64
# normalized_data_380: shape=(13842543,), dtype=float64
# normalized_data_381: shape=(13841191,), dtype=float64
# normalized_data_382: shape=(13938926,), dtype=float64
# normalized_data_383: shape=(13825687,), dtype=float64
# normalized_data_384: shape=(13890208,), dtype=float64
# normalized_data_385: shape=(13882497,), dtype=float64
# normalized_data_386: shape=(13908129,), dtype=float64
# normalized_data_387: shape=(13731065,), dtype=float64
# normalized_data_388: shape=(13800037,), dtype=float64
# normalized_data_389: shape=(13930554,), dtype=float64
# normalized_data_39: shape=(13821699,), dtype=float64
# normalized_data_390: shape=(13820493,), dtype=float64
# normalized_data_391: shape=(13787264,), dtype=float64
# normalized_data_392: shape=(13782608,), dtype=float64
# normalized_data_393: shape=(13786176,), dtype=float64
# normalized_data_394: shape=(13775834,), dtype=float64
# normalized_data_395: shape=(13813589,), dtype=float64
# normalized_data_396: shape=(13906895,), dtype=float64
# normalized_data_397: shape=(13840301,), dtype=float64
# normalized_data_398: shape=(13856963,), dtype=float64
# normalized_data_399: shape=(13768209,), dtype=float64
# normalized_data_4: shape=(13892215,), dtype=float64
# normalized_data_40: shape=(13803273,), dtype=float64
# normalized_data_400: shape=(13885023,), dtype=float64
# normalized_data_401: shape=(13904040,), dtype=float64
# normalized_data_402: shape=(13784612,), dtype=float64
# normalized_data_403: shape=(13769206,), dtype=float64
# normalized_data_404: shape=(13937137,), dtype=float64
# normalized_data_405: shape=(13895672,), dtype=float64
# normalized_data_406: shape=(13872596,), dtype=float64
# normalized_data_407: shape=(13788512,), dtype=float64
# normalized_data_408: shape=(13904935,), dtype=float64
# normalized_data_409: shape=(13900380,), dtype=float64
# normalized_data_41: shape=(13881305,), dtype=float64
# normalized_data_410: shape=(13941864,), dtype=float64
# normalized_data_411: shape=(13832621,), dtype=float64
# normalized_data_412: shape=(13919303,), dtype=float64
# normalized_data_413: shape=(13907628,), dtype=float64
# normalized_data_414: shape=(13769712,), dtype=float64
# normalized_data_415: shape=(13828983,), dtype=float64
# normalized_data_416: shape=(13924204,), dtype=float64
# normalized_data_417: shape=(13852989,), dtype=float64
# normalized_data_418: shape=(13800919,), dtype=float64
# normalized_data_419: shape=(13912622,), dtype=float64
# normalized_data_42: shape=(13779491,), dtype=float64
# normalized_data_420: shape=(13817450,), dtype=float64
# normalized_data_421: shape=(13903727,), dtype=float64
# normalized_data_422: shape=(13763753,), dtype=float64
# normalized_data_423: shape=(13837991,), dtype=float64
# normalized_data_424: shape=(13861329,), dtype=float64
# normalized_data_425: shape=(13768612,), dtype=float64
# normalized_data_426: shape=(13880405,), dtype=float64
# normalized_data_427: shape=(13871802,), dtype=float64
# normalized_data_428: shape=(14011571,), dtype=float64
# normalized_data_429: shape=(13789107,), dtype=float64
# normalized_data_43: shape=(13898223,), dtype=float64
# normalized_data_430: shape=(13785312,), dtype=float64
# normalized_data_431: shape=(13816869,), dtype=float64
# normalized_data_432: shape=(13828137,), dtype=float64
# normalized_data_433: shape=(13818423,), dtype=float64
# normalized_data_434: shape=(13920905,), dtype=float64
# normalized_data_435: shape=(13797910,), dtype=float64
# normalized_data_436: shape=(13864792,), dtype=float64
# normalized_data_437: shape=(13865708,), dtype=float64
# normalized_data_438: shape=(13800809,), dtype=float64
# normalized_data_439: shape=(13796416,), dtype=float64
# normalized_data_44: shape=(13773655,), dtype=float64
# normalized_data_440: shape=(13865567,), dtype=float64
# normalized_data_441: shape=(13904703,), dtype=float64
# normalized_data_442: shape=(13793979,), dtype=float64
# normalized_data_443: shape=(13887655,), dtype=float64
# normalized_data_444: shape=(13779161,), dtype=float64
# normalized_data_445: shape=(13920032,), dtype=float64
# normalized_data_446: shape=(13822484,), dtype=float64
# normalized_data_447: shape=(13766160,), dtype=float64
# normalized_data_448: shape=(13837890,), dtype=float64
# normalized_data_449: shape=(13905319,), dtype=float64
# normalized_data_45: shape=(13818024,), dtype=float64
# normalized_data_450: shape=(13782953,), dtype=float64
# normalized_data_451: shape=(13758453,), dtype=float64
# normalized_data_452: shape=(13882089,), dtype=float64
# normalized_data_453: shape=(13789757,), dtype=float64
# normalized_data_454: shape=(13825206,), dtype=float64
# normalized_data_455: shape=(13884632,), dtype=float64
# normalized_data_456: shape=(13788437,), dtype=float64
# normalized_data_457: shape=(13791218,), dtype=float64
# normalized_data_458: shape=(13726539,), dtype=float64
# normalized_data_459: shape=(13805630,), dtype=float64
# normalized_data_46: shape=(13884132,), dtype=float64
# normalized_data_460: shape=(13801165,), dtype=float64
# normalized_data_461: shape=(13818957,), dtype=float64
# normalized_data_462: shape=(13960291,), dtype=float64
# normalized_data_463: shape=(13772132,), dtype=float64
# normalized_data_464: shape=(13766466,), dtype=float64
# normalized_data_465: shape=(13925508,), dtype=float64
# normalized_data_466: shape=(13862817,), dtype=float64
# normalized_data_467: shape=(13888587,), dtype=float64
# normalized_data_468: shape=(13771291,), dtype=float64
# normalized_data_469: shape=(13823460,), dtype=float64
# normalized_data_47: shape=(13729762,), dtype=float64
# normalized_data_470: shape=(13837744,), dtype=float64
# normalized_data_471: shape=(13916496,), dtype=float64
# normalized_data_472: shape=(13771968,), dtype=float64
# normalized_data_473: shape=(13814289,), dtype=float64
# normalized_data_474: shape=(13787843,), dtype=float64
# normalized_data_475: shape=(13925529,), dtype=float64
# normalized_data_476: shape=(13970969,), dtype=float64
# normalized_data_477: shape=(13804969,), dtype=float64
# normalized_data_478: shape=(13856402,), dtype=float64
# normalized_data_479: shape=(13761674,), dtype=float64
# normalized_data_48: shape=(13887212,), dtype=float64
# normalized_data_480: shape=(13903193,), dtype=float64
# normalized_data_481: shape=(13763949,), dtype=float64
# normalized_data_482: shape=(13923854,), dtype=float64
# normalized_data_483: shape=(13880090,), dtype=float64
# normalized_data_484: shape=(13767299,), dtype=float64
# normalized_data_485: shape=(13890866,), dtype=float64
# normalized_data_486: shape=(13782238,), dtype=float64
# normalized_data_487: shape=(13770833,), dtype=float64
# normalized_data_488: shape=(13765749,), dtype=float64
# normalized_data_489: shape=(13902798,), dtype=float64
# normalized_data_49: shape=(13804768,), dtype=float64
# normalized_data_490: shape=(13823565,), dtype=float64
# normalized_data_491: shape=(13769746,), dtype=float64
# normalized_data_492: shape=(13873115,), dtype=float64
# normalized_data_493: shape=(11238797,), dtype=float64
# normalized_data_494: shape=(13788690,), dtype=float64
# normalized_data_495: shape=(13905196,), dtype=float64
# normalized_data_496: shape=(13787155,), dtype=float64
# normalized_data_497: shape=(13840260,), dtype=float64
# normalized_data_498: shape=(13894224,), dtype=float64
# normalized_data_499: shape=(13782304,), dtype=float64
# normalized_data_5: shape=(13883484,), dtype=float64
# normalized_data_50: shape=(13787938,), dtype=float64
# normalized_data_51: shape=(13779084,), dtype=float64
# normalized_data_52: shape=(13778375,), dtype=float64
# normalized_data_53: shape=(13745381,), dtype=float64
# normalized_data_54: shape=(13835412,), dtype=float64
# normalized_data_55: shape=(13858936,), dtype=float64
# normalized_data_56: shape=(13926881,), dtype=float64
# normalized_data_57: shape=(13808702,), dtype=float64
# normalized_data_58: shape=(13771472,), dtype=float64
# normalized_data_59: shape=(13913723,), dtype=float64
# normalized_data_6: shape=(13776051,), dtype=float64
# normalized_data_60: shape=(13814582,), dtype=float64
# normalized_data_61: shape=(13874771,), dtype=float64
# normalized_data_62: shape=(13895640,), dtype=float64
# normalized_data_63: shape=(13930037,), dtype=float64
# normalized_data_64: shape=(13913783,), dtype=float64
# normalized_data_65: shape=(13918790,), dtype=float64
# normalized_data_66: shape=(13806718,), dtype=float64
# normalized_data_67: shape=(13797908,), dtype=float64
# normalized_data_68: shape=(13820714,), dtype=float64
# normalized_data_69: shape=(13769844,), dtype=float64
# normalized_data_7: shape=(13829829,), dtype=float64
# normalized_data_70: shape=(13771332,), dtype=float64
# normalized_data_71: shape=(13718059,), dtype=float64
# normalized_data_72: shape=(13957249,), dtype=float64
# normalized_data_73: shape=(13846253,), dtype=float64
# normalized_data_74: shape=(13836668,), dtype=float64
# normalized_data_75: shape=(13771333,), dtype=float64
# normalized_data_76: shape=(13822891,), dtype=float64
# normalized_data_77: shape=(13899114,), dtype=float64
# normalized_data_78: shape=(13785390,), dtype=float64
# normalized_data_79: shape=(13889179,), dtype=float64
# normalized_data_8: shape=(13895864,), dtype=float64
# normalized_data_80: shape=(14011810,), dtype=float64
# normalized_data_81: shape=(13775282,), dtype=float64
# normalized_data_82: shape=(13821278,), dtype=float64
# normalized_data_83: shape=(13932744,), dtype=float64
# normalized_data_84: shape=(13900187,), dtype=float64
# normalized_data_85: shape=(13775441,), dtype=float64
# normalized_data_86: shape=(13909876,), dtype=float64
# normalized_data_87: shape=(13908147,), dtype=float64
# normalized_data_88: shape=(13930854,), dtype=float64
# normalized_data_89: shape=(13809142,), dtype=float64
# normalized_data_9: shape=(13888895,), dtype=float64
# normalized_data_90: shape=(13800713,), dtype=float64
# normalized_data_91: shape=(13823863,), dtype=float64
# normalized_data_92: shape=(13783080,), dtype=float64
# normalized_data_93: shape=(13798097,), dtype=float64
# normalized_data_94: shape=(13843810,), dtype=float64
# normalized_data_95: shape=(13770026,), dtype=float64
# normalized_data_96: shape=(13873151,), dtype=float64
# normalized_data_97: shape=(13891967,), dtype=float64
# normalized_data_98: shape=(13781877,), dtype=float64
# normalized_data_99: shape=(13791020,), dtype=float64
#
# Sample data:
# [0.34473249 0.34473249 0.34473249 1.03419746 0.34473249]

# %% [markdown]
# This code will:
# 1. Open the first H5 file in read mode
# 2. Print the complete structure of the file showing all datasets and their properties
# 3. Load the first dataset found in the file
# 4. Show a sample of the loaded data (first 5 elements)
#
# This will help us understand the structure and content of the H5 files before further processing.

# %%
from tqdm import tqdm
import numpy as np

# Dictionary to store 99th percentiles for each wavelength
percentiles = {}

# Process each h5 file
for h5_file in tqdm(h5_files, desc="Processing H5 files"):
    # Extract wavelength from filename
    wavelength = h5_file.name.split('_')[0].replace('aia', '')

    with h5py.File(h5_file, 'r') as f:
        # Assuming data is stored in a dataset called 'data'
        for key in f.keys():
            if isinstance(f[key], h5py.Dataset):
                data = f[key][:]
                break
            elif isinstance(f[key], h5py.Group):
                # Try to get the first dataset in the group
                for subkey in f[key].keys():
                    if isinstance(f[key][subkey], h5py.Dataset):
                        data = f[key][subkey][:]
                        break
                break

        # Calculate 99th percentile
        p99 = np.percentile(data, 99)

        if wavelength in percentiles:
            percentiles[wavelength].append(p99)
        else:
            percentiles[wavelength] = [p99]

# Calculate mean of 99th percentiles for each wavelength
mean_percentiles = {wave: np.mean(vals) for wave, vals in percentiles.items()}

# Create DataFrame for better visualization
df_percentiles = pd.DataFrame({
    'Wavelength': list(mean_percentiles.keys()),
    '99th Percentile': list(mean_percentiles.values())
})
df_percentiles = df_percentiles.sort_values('Wavelength')
df_percentiles
# Out:
# Processing H5 files: 100%|██████████| 38/38 [00:09<00:00,  4.15it/s]
#   Wavelength  99th Percentile
# 0        131        29.702076
# 1        171       730.570419
# 3        193       922.675491
# 2         94         9.519744

# %%
plt.figure(figsize=(10, 6))
plt.bar(df_percentiles['Wavelength'], df_percentiles['99th Percentile'])
plt.title('99th Percentile Pixel Intensity by AIA Wavelength')
plt.xlabel('Wavelength (Å)')
plt.ylabel('99th Percentile Intensity')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
